# %% [markdown]
# #About Dataset
# salaries dataset generally provides information about the employees of an organization in relation to their compensation. It typically includes details such as how much each employee is paid (their salary), their job titles, the departments they work in, and possibly additional information like their level of experience, education, and employment history within the organization.

# %% [markdown]
# # Features
# - 'Id'
# - 'EmployeeName'
# - 'JobTitle'
# - 'BasePay'
# - 'OvertimePay'
# - 'OtherPay'
# - 'Benefits'
# - 'TotalPay' -> salary
# - 'TotalPayBenefits'
# - 'Year'
# - 'Notes'
# - 'Agency'
# - 'Status'

# %% [markdown]
# # Tasks
#
# 1. **Basic Data Exploration**: Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column.
#
# 2. **Descriptive Statistics**: Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.
#
# 3. **Data Cleaning**: Handle missing data by suitable method with explain why you use it.
#
# 4. **Basic Data Visualization**: Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.
#
# 5. **Grouped Analysis**: Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.
#
# 6. **Simple Correlation Analysis**: Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.
#
# 8. **Summary of Insights**: Write a brief report summarizing the findings and insights from the analyses.

# %% [markdown]
# # Very Important Note
# There is no fixed or singular solution for this assignment, so if anything is not clear, please do what you understand and provide an explanation.

# %%
import pandas as pd
import numpy as np

# Load your dataset
df = pd.read_csv('Salaries.csv')
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %% [markdown]
# Task 1 :  **Basic Data Exploration**: Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column.

# %%
#number of coloumns and rows
num_columns = len(df.columns)
num_rows = len(df)
print("number of coloumns :", num_columns)
print ("number of rows: ",num_rows) 

#check the data types of each coloumn 
data_types = df.dtypes
print("columns data type : ", data_types)

#missing values 
missing = df.isnull().sum()
print("missing values :", missing)
# Out:
# number of coloumns : 13
# number of rows:  148654
# columns data type :  Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status              float64
# dtype: object
# missing values ://n Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %% [markdown]
# Task 2 : **Descriptive Statistics** : Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.

# %%
mean_salary = df['TotalPay'].mean()
median_salary = df['TotalPay'].median()
mode_salary = df['TotalPay'].mode()[0]  # Mode might have multiple values, we select the first one
min_salary = df['TotalPay'].min()
max_salary = df['TotalPay'].max()
std_salary = df['TotalPay'].std()

print("Mean salary:", mean_salary)
print("Median salary:", median_salary)
print("Mode salary:", mode_salary)
print("Minimum salary:", min_salary)
print("Maximum salary:", max_salary)
print("rang of salaries: ", max_salary-min_salary)
print("standard deviation:", std_salary)
# Out:
# Mean salary: 74768.32197169267
# Median salary: 71426.60999999999
# Mode salary: 0.0
# Minimum salary: -618.13
# Maximum salary: 567595.43
# rang of salaries:  568213.56
# standard deviation: 50517.00527394987

# %% [markdown]
# Task 3 : **Data Cleaning**: Handle missing data by suitable method with explain why you use it.

# %%
#fill the empty cells in the benifets,BasePay coloumns with zero 
df['Benefits'].fillna(0, inplace=True)
df['BasePay'].fillna(0, inplace=True)
df['OvertimePay'].fillna(0, inplace=True)
df['OtherPay'].fillna(0, inplace=True)

#remove notes and Status coloumn because all cells are empty

df.drop(columns=['Notes']) 
df.drop(columns=['Status'])

print(df.isnull().sum())
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# dtype: int64

# %% [markdown]
# Task 4 :  **Basic Data Visualization** : Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.

# %%
# Create a histogram to visualize the distribution of salaries
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
plt.hist(df['TotalPay'], bins=20, color='skyblue', edgecolor='black')  # Adjust the number of bins as needed
plt.title('Salary Distribution')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.grid(True)
plt.show() 

# Get unique values in the 'job_employee' column
unique_job_titles = df['TotalPay'].unique()
for job_title in unique_job_titles:
    print(job_title) 



fire_department_count = df['JobTitle'].str.contains('FIRE').sum()
police_department_count = df['JobTitle'].str.contains('POLICE').sum()

# Create a bie chart
departments = ['FIRE DEPARTMENT', 'POLICE DEPARTMENT']
counts = [fire_department_count, police_department_count]

plt.figure(figsize=(8, 8))
plt.pie(counts, labels=departments, autopct='%1.1f%%', startangle=90, colors=['red', 'blue'])
plt.title('Proportion of Fire and Police Departments')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()
# Out:
# 567595.43
# 538909.28
# 335279.91
# 332343.61
# 326373.19
# 316285.74
# 315981.05
# 307899.46
# 303427.55
# 302377.73
# 299494.17
# 297608.92
# 294580.02
# 292671.62
# 286347.05
# 286213.86
# 284720.43
# 278569.21
# 276434.22
# 274550.25
# 274190.27
# 273771.21
# 273702.71
# 270672.63
# 270324.91
# 267992.59
# 265784.56
# 265463.46
# 264074.6
# 261366.14
# 260297.66
# 259927.11
# 259684.88
# 258588.39
# 258364.22
# 257540.09
# 257124.44
# 253269.44
# 251935.01
# 251685.16
# 250595.39
# 250408.49
# 250339.35
# 250317.93
# 250122.04
# 249375.02
# 249293.3
# 248895.77
# 248718.64
# 248434.39
# 247254.61
# 246305.62
# 244687.81
# 242742.85
# 241286.42
# 241211.17
# 240846.3
# 240019.1
# 239426.36
# 238879.2
# 238803.56
# 238551.88
# 238501.05
# 238479.28
# 237837.73
# 237708.83
# 237344.41
# 236833.82
# 236200.92
# 234865.2
# 234848.11
# 233944.48
# 233464.63
# 233357.28
# 232702.58
# 232486.72
# 232007.77
# 231712.8
# 231652.13
# 231592.25
# 231306.04
# 231104.97
# 230906.51
# ...

# %% [markdown]
# Task 5 : **Grouped Analysis** : Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.

# %%
# Function to extract department from job_employee
def extract_department(job_employee):
    if 'FIRE' in job_employee:
        return 'FIRE'
    elif 'POLICE' in job_employee:
        return 'POLICE'
    else:
        return 'NON'

# Create a new column for department
df['department'] = df['JobTitle'].apply(extract_department)

summary_stats_1 = df.groupby('department')['TotalPay'].agg(['mean', 'median', 'count'])
print(summary_stats_1)
# Out:
#                      mean      median   count
# department
# FIRE        145005.665483  144821.790    1459
# NON          73151.502065   70170.430  144683
# POLICE      127097.171660  127177.465    2512

# %% [markdown]
# Task 6 : **Simple Correlation Analysis**: Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.

# %%
#  scatter plot between sallary and year
plt.figure(figsize=(8, 6))
plt.scatter(df['Year'], df['TotalPay'], color='blue', alpha=0.5)
plt.title('Salary vs. Year')
plt.xlabel('Year')
plt.ylabel('Salary')
plt.grid(True)
plt.show() 

#  scatter plot between sallary and department
plt.figure(figsize=(8, 6))
plt.scatter(df['department'], df['TotalPay'], color='blue', alpha=0.5)
plt.title('Salary vs. department')
plt.xlabel('department')
plt.ylabel('Salary')
plt.grid(True)
plt.show() 

#  scatter plot between sallary and BasePay
plt.figure(figsize=(8, 6))
plt.scatter(df['BasePay'], df['TotalPay'], color='blue', alpha=0.5)
plt.title('Salary vs. BasePay')
plt.xlabel('BasePay')
plt.ylabel('Salary')
plt.grid(True)
plt.show() 

#  scatter plot between sallary and Benefits

plt.figure(figsize=(8, 6))
plt.scatter(df['Benefits'], df['TotalPay'], color='blue', alpha=0.5)
plt.title('Salary vs. Year')
plt.xlabel('Year')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

# %% [markdown]
# Task 7 : **Summary of Insights**: Write a brief report summarizing the findings and insights from the analyses.

# %% [markdown]
# The salary data appears normally distributed with a mean of $74,768.32, a median of $71,426.61, and a mode of $0. This suggests most salaries fall within a predictable range, with outliers at both ends. The range of salaries is vast, spanning from -$618.13 to $567,595.43, indicating a significant income gap.For the standard deviation of $50,517.01 further emphasizes this variability.One graph showed a positive correlation between salary and base pay, with police officers receiving a larger proportion of variable pay compared to firefighters.Another graph depicted an upward trend in average annual salary across four years, although specific values were unclear due to missing labels.

# %% [markdown]
# # Good Luck!
